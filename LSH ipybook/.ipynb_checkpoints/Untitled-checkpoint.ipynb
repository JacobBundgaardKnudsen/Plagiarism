# %%
import inspect, os
from gensim.parsing import preprocessing as genPreProc
from gensim.parsing.preprocessing import preprocess_string
from spacy import load

# %%
def loadDoc(dataPath):
    with open(dataPath, encoding="utf8", errors='ignore') as loadedDoc:
        doc = loadedDoc.read()
    return doc

# %%
nlp = load('en')
srcfolder = os.path.dirname(os.path.abspath(inspect.stack()[0][1]))
datafolder = os.path.join(srcfolder, "testDocuments")   # change to ats_corpus for large data set
filepath = os.path.join(datafolder, "testDoc5.txt")
    
document = loadDoc(filepath)

document = loadDoc(filepath)
genSettings2 = [lambda x: x.lower(), genPreProc.remove_stopwords, genPreProc.stem]
step1preprocess = ' '.join(preprocess_string(document, filters=genSettings2))
sentenceSplit = list(nlp(step1preprocess).sents)

genSettings3 = [lambda x: genPreProc.strip_non_alphanum(x), genPreProc.strip_multiple_whitespaces]
sentencePreprocess = [' '.join(preprocess_string(str(ite), filters=genSettings3)) for ite in sentenceSplit]

# %%
sentencePreprocess
# Out:
# ['x acapulco juárez spanish akaˈpulko ðe ˈxwaɾes commonli call acapulco city municip major seaport state guerrero pacif coast mexico 380 kilometr 240 mi south mexico city',
#  'acapulco locat deep semicircular bai port earli coloni period mexico history',
#  'port ship cruis line run panama san francisco california unit states',
#  'citi acapulco largest state far larger state capit chilpancingo',
#  'acapulco mexico largest beach balneario resort city th citi mexico oldest beach resorts came promin 1940 1960 getawai hollywood star millionaires',
#  'acapulco popular tourist resort massiv upsurg gang violenc murder 2014 longer attract tourists come mexico itself',
#  'deadliest citi mexico third deadliest citi world govern warn citizen travel there',
#  '2016',
#  '918 murders homicid rate highest world 103 100 000',
#  'septemb 2018 city entir polic forc disarm military suspicion infiltr drug gangs',
#  'health crisi develop larg quantiti uncollect refus build streets th resort area divid parts north end bai traditional area encompass area parqu papagayo zócalo beach caleta caletilla main bai known zona dorada golden zone spanish famou mid 20th centuri vacationed south end diamante diamond spanish domin newer luxuri high ris hotel condominiums th acapulco come nahuatl languag aca pōl co mean where reed destroi wash away',
#  'de juárez ad offici 1885 honor benito juárez presid mexico 1806 1872',
#  'seal citi show broken reed cane',
#  'island municip capul philippines deriv acapulco capul western end trans pacif sail rout acapulco spanish colony histori pre columbian by 8th centuri acapulco bai area small cultur domin olmecs number pre hispan period end 1520s',
#  'acapulco bai itself olmec sites playa larga hill known el guitarrón',
#  'olmec',
#  'influenc caus small spread out villag coalesc larger entiti build ceremoni centers later teotihuacan influenc wai cuernavaca chilpancingo',
#  'mayan influenc arriv isthmu tehuantepec oaxaca',
#  'histori known archaeolog artifact here especi playa hornos pie la cuesta tambuco in 11th century new wave migrat nahua coixa came here',
#  'peopl anteced aztecs',
#  'later 15th century year militari struggle acapulco aztec empir reign ahuizotl 1486 1502',
#  'annex tributari provinc name tepecuacuilco',
#  'however transitory aztec establish unorgan militari post city outskirts',
#  'citi territori control yopes continu defend live arriv spanish 1520s 16th centuri there stori acapulco bai discov europeans',
#  'state year spanish conquest aztec empire hernán corté sent explor west gold',
#  'explor subdu area 1523 captain saavedra cerón author corté settlement here',
#  'state bai discov decemb 13 1526 small ship name el tepach santiago captain santiago guevara th encomendero establish 1525 cacahuatepec modern acapulco municipality',
#  '1531 number spaniards notabl juan rodriguez villafuerte left oaxaca coast found villag villafuert citi acapulco stands',
#  'villafuert unabl subdu local nativ peoples eventu result yopa rebellion region cuautepec',
#  'hernán corté oblig send vasco porcayo negoti indigen peopl give concessions',
#  'provinc acapulco encomendero rodriguez villafuert receiv tax form cocoa cotton corn corté establish acapulco major port earli 1530s major road mexico citi port construct 1531',
#  'wharf name marqués construct 1533 bruja point diamond point',
#  'soon after area alcadia major provinc town spanish trade far east acapulco promin posit economi new spain',
#  'galleon start arriv asia 1550 year thirti spanish famili sent live mexico citi perman base european residents',
#  'acapulco second import port veracruz direct trade philippines',
#  'trade focu yearli manila acapulco galleon trade nexu kind commun new spain europ asia',
#  '1573 port grant monopoli manila trade',
#  '17th 19th centuri the galleon trade yearli run mid 16th centuri earli 19th',
#  'luxuri item brought new spain attract attent english dutch pirates franci drake henri morgan thoma cavendish call the black ship',
#  'dutch fleet invad acapulco 1615 destroi town driven off',
#  'fort san diego built follow year protect port cargo arriv ships',
#  'fort destroi earthquak',
#  '1776 rebuilt 1778',
#  '1783 at begin 19th century king charl',
#  'iv declar acapulco ciudad offici essenti spanish crown',
#  'however long after mexican war independ began',
#  '1810 josé maría morelo',
#  'y pavón attack burnt city defeat royalist command francisco paré battl tre palos',
#  'independ mexico 1821',
#  'end run manila galleon acapulco',
#  'import port recov california gold rush mid 19th century ship go come panama stop here',
#  'citi besieg 19 april 1854 antonio lópez santa anna guerrero leadership rebel issu plan ayutla',
#  'unsuccess week fighting santa anna retreated 20th centuri in 1911 revolutionari forc took main plaza',
#  'acapulco in 1920 princ wale the futur king edward viii visit area',
#  'impress saw recommend place compatriot europe make popular elit there',
#  'origin hotel trade infrastructur built east texa businessman name albert b pullen corrigan texas area known old acapulco',
#  '1933 carlo barnard start section hotel el mirador 12 room cliff la quebrada',
#  'wolf schoenborn purchas larg amount undevelop land albert pullen built la america hotel in mid 1940s commerci wharf warehous built',
#  'earli 1950s presid miguel alemán valdé upgrad port infrastructure instal electr lines drainag systems road highwai connect port mexico city th economi grew foreign invest increas it',
#  '1950s acapulco fashion place millionair hollywood star elizabeth taylor frank sinatra eddi fisher brigitt bardot',
#  '1963 hollywood movi fun acapulco star elvi presley set acapulco film took place usa',
#  'swing musician teddi stauffer call mister acapulco hotel manag villa vera casablanca attract celebr acapulco from popul 4 000 5 000 1940s earli 1960s acapulco popul 50 000',
#  '1958 dioces acapulco creat pope',
#  'piu xii',
#  'archdioces 1983 dure',
#  '1960 1970s new hotel resort built accommod transport cheaper',
#  'longer necessari millionair spend holidai acapulco foreign mexican middl class afford travel here',
#  'however hotel built south bay old hotel 1950 lost grandeur',
#  '1968 summer olymp neighbor mexico city acapulco host sail then yachting events in 1970s signific expans port th miss univers 1978 pageant took place city',
#  '1983 singer songwrit juan gabriel wrote song amor eterno pai homag acapulco',
#  'song famous record rocio durcal',
#  'additionally acapulco hometown actress singer comedian aída pierce fame 1980s 1990 decad 21st century dur 1990s road known ruta del sol built cross mountain mexico citi acapulco',
#  'journei take half hours make acapulco favorit weekend destin mexico citi inhabitants',
#  'time period econom impact acapulco tourist destin increas posit result new type servic emerg like colegio nautilus',
#  'educ project back state government creat famili local foreign investor businessmen live acapulco need bilingu intern educ children th port continu grow 1996 new privat company api acapulco creat manag operations',
#  'consolid oper acapulco major port car export pacific th citi devast hurrican paulin 1997',
#  'storm strand tourist left 100 dead city',
#  'victim shantytown built steep hillsid surround city',
#  'victim swept awai thirty foot wave 150 mph 240 km h winds',
#  'main road avenida costera fast mov three foot deep river sludge 21st centuri in 21st century mexican drug war neg effect tourism acapulco rival drug traffick fight guerrero coast rout bring drug south america soldier fight cartel 2006 a major gun battl 18 gunmen soldier took place summer 2009 old acapulco seasid area last hour kill 16 gunmen soldiers',
#  'came swine flu outbreak earlier year nearli paralyz mexican economy forc hotel discount bring tourist back',
#  'however hotel occup 2009 percent year before',
#  'death arturo beltran leyva decemb 2009 result infight differ group beltran leyva cartel gang violenc continu plagu acapulco 2010 2011 notabl 15 dy drug rel violenc march 13 2010 15 death januari 8 2011',
#  'incident dead member citi polic brother ex mayor second incident headless bodi 15 young men dump near plaza sendero shop center',
#  'august 20 2011',
#  'mexican author report headless bodi acapulco place city main tourist area cut multipl pieces on februari 4 2013 spanish men ti rob spanish women gang rap mask gunmen storm beach hous outskirt acapulco accusations victim decid press charges',
#  'septemb 28 2014 mexican politician call braulio zaragoza gun el mirador hotel city',
#  'leader conserv opposit nation action parti pan southern guerrero state',
#  'politician target drug cartel oper area',
#  'investig way arrest made',
#  'insecur individu involv drug cartel cost citi acapulco popular nation intern tourists',
#  'state dirección gener aeronáutica civil number intern flyer come acapulco decreas 355 760 flyer regist 2006 52 684 flyer year 2015 number intern tourist fly acapulco drop 85 interv years geographi climat',
#  'the city locat pacif coast mexico state guerrero classifi state seven regions divid rest guerrero coast costa grand costa chica forti percent municip mountain terrain',
#  'percent semi flat percent flat',
#  'altitud vari sea level 1 699 metr 5 574 feet',
#  'highest peak potrero san nicola alto camarón',
#  'major river papagayo run municipality number arroyos',
#  'small lagoons tre palo coyuca',
#  'number thermal springs acapulco featur tropic wet dry climat köppen aw hot distinct wet dry seasons temperatur season resort farther north mexico',
#  'vari depend altitude',
#  'warmest area sea citi is',
#  'tropic storm hurrican threat november',
#  'forest area tend lose leav winter dry season evergreen pine highest elevations',
#  'fauna consist deer small mammals wide varieti land sea birds marin anim',
#  'turtles th temperatur sea',
#  'stable low 82 f',
#  '28 c januari',
#  'march high 86 f',
#  '30 c august govern a seat municipality citi acapulco govern author 700 communities territori 1 880 60 km2',
#  'municip border municip chilpancingo juan r escudero tierra colorada san marcos coyuca benítez pacif ocean south th metropolitan area municip acapulco juárez coyuca benitez',
#  'area popul a 2005 786 830 demograph popul acapulco popul citi state guerrero accord result ii popul hous censu 2010 carri nation institut statist geographi inegi censu date june 12 2010 citi total popul',
#  '673 479 inhabitants amount 324 746 men 348 733 women',
#  'consid twenty second popul citi mexico tenth popul metropolitan area mexico',
#  'citi highest concentr popul homonym municipality repres 85 25 percent 789 971 inhabitants th metropolitan area acapulco town municip acapulco juárez municip coyuca benítez',
#  'agreement count offici delimit realiz 2010 altogeth nation institut statist geography nation council popul secretariat social development metropolitan area acapulco group total',
#  '863 431 inhabit surfac 3 538 5 km² place tenth popul district mexico',
#  'estim accord studi nation autonom univers mexico climat geography carri 2002 2015 2020 citi acapulco exce million inhabitants nota source instituto nacion estadística y geografía popul censu 1895 1990 2000 2010 popul count 1995 2005 economi',
#  'tourism main econom activ municip center acapulco bay',
#  'seventy thre percent municipality popul involv commerce relat tourism port',
#  'mine manufactur emploi percent percent dedic agriculture',
#  'industri product limit bottling milk products cement products',
#  'ic energi production',
#  'agricultur product includ tomatoes corn watermelon beans green chili peppers melons tourism acapulco mexico oldest coastal tourist destinations reach promin 1950 place hollywood star millionair vacat beach exot locale',
#  'modern times tourist acapulco face problem corrupt local polic steal monei extort intimid visitor threat jail th citi divid tourist areas tradit acapulco old port hotel like hotel lo flamingos own person johnni weissmul john wayn located northern end bay',
#  'anchor attract beach caleta caletilla cliff diver la quebrada citi square known el zocalo',
#  'heydai acapulco ran late 30 60s',
#  'start late 50s develop continu 80s acapulco dorado develop 1950 1970s 25 minut acapulco intern airport',
#  'area present tourist influx port run acapulco bay icacos pass costera miguel aleman avenue main one papagayo park',
#  'hotel avail them acapulco diamante known punta diamante newest develop invest port consist exclus hotel resort intern chains residenti complexes luxuri condominium privat villas spas restaurants shop area golf cours make exclus place country',
#  'start scenic highwai la brisas includ puerto marqué punta diamant extend barra vieja beach',
#  '10 minut acapulco intern airport acapulco diamante known punta diamante newest develop invest port consist exclus hotel resort intern chains residenti complexes luxuri condominium privat villas spas restaurants shop area golf course connect highwai la escenica includ playa diamant puerto marqués stretch airport mountain separ bay',
#  'area boulevard la naciones transport car limousin golf cart',
#  'older section town cater middl class exclus mexican clientele glitzier newer section cater mexican upper classes ventur',
#  'older tradit town acapulco reput high energi parti town nightlif long draw citi tourists',
#  'novemb april luxuri liner stop daili includ ship ms queen victoria ms rotterdam crystal harmony princess line ships',
#  'despit acapulco intern fame visitor central mexico especi affluent mexico city',
#  'acapulco embark port mexican cruis line ocean star cruises for christma season 2009 acapulco receiv 470 000 visitors mexican nationals ad 785 million peso economy',
#  'eighti percent arriv land eighteen percent air',
#  'area 25 000 condominiums function second home mexican owners',
#  'acapulco popular mexican celebr wealthy lui miguel plácido domingo dolor olmedo maintain home here problem while glitz glamour acapulco famou remains 20th centuri on citi taken less posit reputations',
#  'consid passé resort eclips newer cancún cabo san lucas',
#  'years number problem develop here especi bai older section city',
#  'larg number wander vendor beaches offer newspap massages recogn problem',
#  'bother tourist simpli want relax beach govern sai difficult eradicate lot unemploy poverti here',
#  'citi small shantytown cling mountainsides popul migrant come look work',
#  'decade drug rel violenc caus massiv problem local tourism trade anoth problem garbag accumul bay',
#  '60 65 ton recent extract bai acapulco nearbi zihuatanejo need done',
#  'trash remov season beach water',
#  'closest them',
#  'however center bai touched',
#  'reason trash wind bai common throw streets river bai itself',
#  'common item clean bai beer bottl car tires',
#  'acapulco seen success area have beach receiv high blue flag certif cleanli water quality gastronomi acapulco gastronomi rich follow typic dish region relleno bake pork varieti veget fruit potatoes raisins carrot chiles',
#  'eaten bread call bolillo pozol soup salsa base it white red green corn meat pork chicken accompani antojitos like tostadas taco tamales',
#  'dish serv weekli thursdai event citi state restaur offer meal special entertainment band dancer celebr impersonators attract acapulco main attract nightlife decades',
#  'nightclub chang name owner frequently for example babi o open nation intern public 1976 differ celebr visit instal mexican singer lui miguel bono u2 sylvest stallone',
#  'nightclub palladium locat escénica avenue locat give nightclub beauti view santa lucia bai night',
#  'dj perform palladium dvbbs tom swoon nervo junki kid inform lobbi poolsid cocktail bar offer free live entertainment',
#  'addition beach bar zone younger crowd go',
#  'locat costera road face ocean featur techno altern rock',
#  'concentr fiesta americana continent plaza hotels',
#  'place tend open earlier inform dress',
#  'bunge jump area well anoth',
#  'enigmat attract acapulco la quebrada cliff divers',
#  'tradit start 1930 young men casual compet dive highest point sea below',
#  'eventually local began ask tip come men dive',
#  'todai diver professionals dive height metr 130 feet inlet seven m 23 ft wide m 13 ft deep prai shrine virgin guadalupe',
#  'decemb 12 feast dai virgin freestyl cliff diver jump sea honor her',
#  'dive rang simpl complic end ocean fire sea lit gasoline make circl flame diver aim for',
#  'spectacl seen public area charg small fee hotel plaza la glorias el mirador bar restaur terrace ther number beach acapulco bai immedi coastline',
#  'bai proper la angosta in quebrada caleta caletilla dominguillo tlacopanocha hornos hornitos honda tamarindo condesa guitarrón icacos playuela playuelilla playa del secreto',
#  'adjoining smaller bai puerto marqué pichilingue la brisas playa roqueta',
#  'face open ocean',
#  'northwest bai pie la cuesta southeast playa revolcadero playa aeromar playa encantada barra vieja',
#  'lagoon area coyuca northwest acapulco bai tre palo southeast',
#  'lagoon mangrov offer boat tours',
#  'tre palo sea turtl nest area protected in addit sunbathing beach bai offer number services boat rentals boat tours horseback riding scuba dive aquat sports',
#  'popular cruis caletilla beach roqueta island place snorkel lunch lighthouse',
#  'underwat statu virgin guadalup here creat 1958 armando quesado memori group diver di here',
#  'scuba div tour come area',
#  'well sunken ships sea mountains cave rock formations',
#  'popular activ deep sea fishing',
#  'major attract sail fishing',
#  'fish caught weigh 89 200 pounds',
#  'sailfish plenti boat captain known bet potenti custom catch anything trip free in old city tradit main squar call zócalo line shade trees café shops',
#  'north end squar nuestra señora la soledad cathedral blue onion shap dome byzantin towers',
#  'build origin construct movi set later adapt church',
#  'acapulco histor build fort san diego locat east main squar origin built 1616 protect citi pirat attacks',
#  'fort partial destroi dutch mid 17th century rebuilt destroi 1776 earthquake',
#  'rebuilt 1783 build seen today unchang renov 2000',
#  'part moat remain bulwark battlements',
#  'todai fort serv museo histórico acapulco acapulco histor museum show port histori pre hispan period independence',
#  'temporari exhibit well th centro internacion convivencia infantil cici sea lif aquat park locat costera miguel aleman',
#  'offer wave pools water slide water toboggans',
#  'dolphin show daili swim dolphin program',
#  'center cater children',
#  'place popular children parqu papagayo larg famili park life s replica spanish galleon space shuttl columbia artifici lakes aviary skate rink rides go kart more th dolor olmedo hous locat tradit downtown acapulco note mural diego rivera adorn it',
#  'olmedo rivera friend olmedo child rivera spent year life here',
#  'time paint nearli nonstop creat outsid wall tile mosaics featur aztec deiti quetzalcoatl',
#  'interior home cover murals',
#  'home museum outsid mural abl seen public ther small museum call casa',
#  'la máscara hous masks dedic masks mexico exampl part world',
#  'collect contain thousand exampl divid seven room call mask world mexico history huichol jaguar alebrij danc guerrero devil death ident fantasy afro indian masks th botan garden acapulco tropic garden locat land own universidad loyola del pacífico',
#  'plant nativ region many peltogyn mexicana purpl stick tree danger',
#  'extinction on cultur event held yearli acapulco festiv internacion la nao take place fort san diego locat near zócalo downtown city',
#  'festiv honor remembr city interact trade orient territori start sixteenth century',
#  'nao festiv consist cultur activ support organ embassi india china japan philippines thailand indonesia south korea',
#  'varieti event film projections music interpret theatr gastronom classes event specif kids th annual french festiv take place acapulco citi offer multitud event cement cultur link mexico france',
#  'main featur fashion gourmet food fair',
#  'cinépoli',
#  'galería diana teatro juan ruíz alarcón present french french literari figur talk specialis subjects',
#  'local nightclub featur french djs',
#  'festiv celebr includ carnival feast san isidro labrador 15 may november craft livestock fair call nao china ther number golf cours',
#  'acapulco includ acapulco princess pierr marqué course design robert trent jone 1972 world cup golf tournament',
#  'mayan palac cours design pedro guericia econom cours call club golf acapulco near convent center',
#  'exclus cours tre vida golf club design robert von hagge',
#  'locat ocean home flock duck',
#  'birds anoth famou sport tournament held acapulco 1993 abierto mexicano telcel 500 atp take place tenni court princess mundo imperial resort locat diamant zone acapulco',
#  'initi plai clai court chang hard court',
#  'event gain popular pass years 2017 tournament took place 27th februari 4th march',
#  'athlet particip competit famou player coupl years novak djokov current rank second rafael nadal posit sixth rank marin cilic number ranking th prize 250 000 00 usd wta 1 200 000 00 usd atp acapulco bullring call plaza toros near caletilla beach',
#  'season run winter call fiesta brava spring break over 100 000 american teenag young adult travel resort area balneario mexico spring break year',
#  'main reason student head mexico 18 year old drink ag versu 21 unit states market tour oper sun ocean',
#  'attract 1990s especi tradit spring break place daytona beach florida enact restrict drink behaviors',
#  'legisl push spring break visit part mexico acapulco destinations in late 1990 earli 2000s cancún favor spring break destin choice',
#  'however cancún taken step control reckless behavior associ event student look someplac new',
#  'led choos acapulco spite fact travelers flight longer expens cancún',
#  'attract glitzi hotel south acapulco famou nightlife',
#  '2008 22 500 student came acapulco spring break',
#  'hotel 2009 econom situat unit states partial scare drug rel violence in februari 2009 state depart issu travel alert direct colleg student plan spring break trip acapulco',
#  'warning a result violent activ spring mexico drug cartel débâcle',
#  'took colleg campus storm school go far warn student risk travel mexico spring break',
#  'new york time track travel penn student spring break acapulco week dissemin email o reilli devot segment show o reilli factor urg student stai awai acapulco',
#  'june 2009 number incid occur drug cartel government',
#  'includ coordin attack polic headquart open battl streets involv large calib weapon grenades',
#  'however incid violenc spring breaker reported transport mani airlin fly acapulco intern airport',
#  'city buse taxi servic place place local choos walk destinations',
#  'however import mode transport govern subsid colectivo cab system',
#  'cab cost 13 peso person ride private',
#  'driver pick passeng long seat available transport destin base first com first serv rules',
#  'colectivo travel design area city main on costera colosio coloso mixtur three',
#  'coloso cab travel mainli old acapulco',
#  'colosio cab travel tourist area acapulco',
#  'costera cab drive coast acapulco hotel visitor located includ old acapulco',
#  'driver partli choice will travel design areas especi slow period day th bu highli complex confus outsider',
#  'far transport goes cheapest form walking acapulco',
#  'expens buse air conditioning cheaper buse not',
#  'tourists acapulco citi govern establish yellow buse acapulco paint them',
#  'buse tourist only certainli nicest uniform bu systems',
#  'buse travel tourist section acapulco drive coast',
#  'buse specif rout destinations gener written windshield shout barker ride seat',
#  'unusu thing privat oper buse fact highli decor personalized decal home mad interior design rang comic book scenes pornography hello kitty',
#  'themes th conflict public transport upgrad 25th june 2016 implement acabus',
#  'acabu infrastructur length 36 2 kilometr 22 5 miles count 16 station spread citi acapulco 5 routes',
#  'project help organ traffic buse specif line road control transport passengers intern relat consul twin town partner citi intern domest teocaltiche 2005 dolor hidalgo 2009 guanajuato city 2010 boca del río 2012 morelia 2013 pend transboundari nomin in 2014 idea nomin manila acapulco galleon trade rout',
#  'initi mexican ambassador unesco filipino ambassador unesco an experts roundtabl meet held univers santo toma ust april 23 2015 prepar philippin possibl transnat nomin manila acapulco galleon trade rout world heritag list',
#  'nomin jointli mexico th follow expert topic discuss roundtabl meeting dr',
#  'celestina boncan tornaviaje dr',
#  'mari jane a bolunia shipyard bicol region mr',
#  'sheldon clyde jago on bobbi orillaneda',
#  'ligaya lacsina underwat archaeology dr',
#  'leovino garcia map cartography fr',
#  'rene javellana s j',
#  'fortif philippines felic sta',
#  'maria food dr',
#  'fernando zialcita textile regalado trota jose histor dimension',
#  'paper present discuss roundtabl meet synthes work document establish route outstand univers value th mexican reiter follow suit prepar route nomination spain back nomin manila acapulco trade rout rout',
#  'unesco world heritag list suggest archiv manila acapulco galleon nomin separ unesco list unesco memori world register acapulco municipality triangl sun refer bibliographi extern link',
#  'offici citi govern websit in spanish q']
